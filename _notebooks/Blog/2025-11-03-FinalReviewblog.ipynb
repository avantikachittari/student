# %% [markdown]
# ---
# layout: post
# title: Final Review Blog- Trimester 1
# description: Retrospect of 3 sprints in tri 1
# toc: true
# breadcrumbs: True
# authors: Avantika
# permalink: /blogs/retrospect
# ---

# %% [markdown]
# How I grade myself at the start of Trimester 1:
#
# | Skill | Mastered (Y/N) | Self Rank (1-5) | Peer Rank (1-5) | Teacher Rank (1-5) | Average | Notes/Evidence |
# |--|--|--|--|--|--|--|
# | 🎯 Core Behaviors |  |  |  |  |  |  |
# | Attendance | ✅ | 5 | 5 |  |  | Consistently attended all classes and meetings on time. |
# | Work Habits | ✅ | 3.5 | 4 |  |  | Completed tasks efficiently, though sometimes needed reminders. |
# | Behavior | ✅ | 4.5 | 4.5 |  |  | Maintained a positive and respectful attitude in class. |
# | Timeliness | ✅ | 5 | 5 |  |  | Turned in all assignments on time. |
# | 💻 Technical Skills |  |  |  |  |  |  |
# | Tech/Cyber Sense | ✅ | 3.5 | 3.5 |  |  | Demonstrated understanding of safe and responsible tech use. |
# | Tech/Cyber Talk | ✅ | 2.8 | 4 |  |  | Communicated tech concepts with peers, but not at a very high level |
# | Tech Growth | ✅ | 3 | 3 |  |  | Showing progress in coding and technical projects. |
# | 🤝 Collaboration |  |  |  |  |  |  |
# | Advocacy | ❌ | 2 | 3 |  |  | Need improvement in speaking up or supporting team ideas. |
# | Communication & Collab | ✅ | 4 | 5 |  |  | Work well in teams and shares ideas my effectively, but could be more precise. |
# | 🎨 Professional Skills |  |  |  |  |  |  |
# | Integrity | ✅ | 5 | 5 |  |  | Consistently honest and ethical in work. |
# | Organization | ✅ | 1.5 | 3 |  |  | Not properly organized. |
# | 📈 TOTALS |  |  |  |  |  |  |
# | 🎯 AVERAGE SCORE |  |  |  |  |  |  |

# %% [markdown]
# How I grade myself at end of Trimester 1:
#
# | Skill | Mastered (Y/N) | Self Rank (1-5) | Peer Rank (1-5) | Teacher Rank (1-5) | Average | Notes/Evidence |
# |--|--|--|--|--|--|--|
# | 🎯 Core Behaviors |  |  |  |  |  |  |
# | Attendance | ✅ | 5 | 4 |  |  | Not many absences. |
# | Work Habits | ✅ | 4 | 4 |  |  | I feel like my work habits have improved since the start of the trimester; however, I still don't think I am perfect and I can improve more. |
# | Behavior | ✅ | 4.5 | 4.5 |  |  | Maintained a positive attitude and respectful behavior in class, but sometimes off task. |
# | Timeliness | ❌ | 3 | 5 |  |  | A lot of my commits were made at one time and I waited a long time to make pull requests instead of getting started earlier. I also put off fixing errors in my code, which caused them to pile up. |
# | 💻 Technical Skills |  |  |  |  |  |  |
# | Tech/Cyber Sense | ✅ | 4.5 | 3.5 |  |  | My cyber sense has improved a lot compared to sprint 1; I can fix and understand my code better now, though I am not perfect. |
# | Tech/Cyber Talk | ✅ | 4 | 4 |  |  | Need to improve clarity and confidence when explaining tech concepts. |
# | Tech Growth | ✅ | 4 | 5 |  |  | Making steady progress in coding skills and understanding new concepts. |
# | 🤝 Collaboration |  |  |  |  |  |  |
# | Advocacy | ✅ | 5 | 5 |  |  | Speaking up for my ideas and supporting team discussions has improved. |
# | Communication & Collab | ✅ | 5 | 5 |  |  | Works effectively with peers and shares ideas clearly. |
# | 🎨 Professional Skills |  |  |  |  |  |  |
# | Integrity | ✅ | 4 | 4 |  |  | Consistently honest and ethical in my work. |
# | Organization | ✅ | 4 | 4 |  |  | Most of my things are somewhat organized; however, there is a lot of room for improvement and areas to fix. |
# | 📈 TOTALS |  |  |  |  |  |  |
# | 🎯 AVERAGE SCORE |  |  |  |  |  |  |

# %% [markdown]
# ## Onbarding hacks
#
# ### Snake Game:
#  Working on this Snake game taught me how small changes can completely transform a game. I improved the visuals with glowing effects, added gameplay mechanics like multiple foods, obstacles, and lives, and upgraded the controls with WASD keys. Adjusting speed and growth settings gave players more flexibility, and redesigning the UI made the game feel modern and polished. Overall, this project showed me how creativity and thoughtful tweaks can make even a simple game exciting and engaging.
#
# What it looks like before you start:
# <img width="930" height="563" alt="Image" src="https://github.com/user-attachments/assets/e372535f-a1a5-4f4c-b3fd-3862c7459a3a" />
#
# What it looks like when you are playing:
#
# <img width="729" height="478" alt="Image" src="https://github.com/user-attachments/assets/d45fffff-5a7b-42fb-9521-d5c7ab0b7540" />
#
#
#
# ### Cookie Clicker:
# I updated the Cookie Clicker game to make it more engaging and visually appealing. The cookie’s appearance was improved, and clicking it now displays a +1 and a cookie symbol for instant feedback. We added a new purchasable Cursor that automatically clicks the cookie, helping players earn cookies faster, and introduced a Portal that costs 500,000 cookies and generates cookies at a much higher rate, giving players a long-term goal. Additionally, the overall layout and interface were polished, making the game cleaner, easier to navigate, and more enjoyable to play.
#
# What it looks like:
#
# <img width="796" height="619" alt="Image" src="https://github.com/user-attachments/assets/4dc70bd6-15de-41f4-b73f-4a62939a4c3b" />

# %% [markdown]
# ## Tools set up

# %%
title: Open Coding 
description: "Class of 2026"
owner_name: John Mortensen
github_username: jm1021 
github_repo: "student" 
baseurl: "/student" 
future: true
remote_theme: jekyll/minima
minima:
  skin: dark
  social_links:
    - { platform: github, user_url: "https://github.com/open-coding-society" }
    - { platform: x, user_url: "https://x.com/Open_Coding" }
    - { platform: youtube, user_url: "https://www.youtube.com/@OpenCodingSociety" } 
plugins:
  - jekyll-remote-theme
  - jekyll-include-cache
header_pages:
  - navigation/blog.md
  - navigation/search.md
  - navigation/about.md
  - navigation/logintoolkit.md

# %% [markdown]
# The site uses the Minima theme with a dark skin, giving it a clean and modern look while being easy on the eyes. This theme is simple yet customizable, making it ideal for displaying coding projects, blogs, and navigation pages. It also supports social links and integrates smoothly with Jekyll plugins for extra functionality.

# %% [markdown]
# ## M&M Game
#
# ### What me and my team did
#
# Strategic NPC placement: We carefully positioned each NPC on the background images so the learning experience felt natural. By placing characters in context with the environment, it became easier for users to know where to focus and how to interact.
#
# Unique roles for each M&M: Each M&M had a specific purpose—some gave quizzes to test knowledge, while others guided users on where to go next. This made the experience interactive and engaging, turning each step into a learning opportunity.
#
# Progression and reward: Completing all the tasks and challenges transformed the player into a rainbow M&M. This not only gave a sense of achievement but also reinforced the idea that learning can be playful and rewarding.
#
# Teamwork and design thinking: Collaborating as a group allowed us to decide NPC placement, assign M&M roles, and create a consistent, educational theme. Every decision was intentional to maximize learning and engagement.
#
# Lessons learned: This project taught me how thoughtful design, interactivity, and clear objectives can make coding lessons more intuitive and fun. Mixing creativity with educational goals created a meaningful and memorable experience for users.
#
# What the first level looks like:
#
# <img width="1440" height="688" alt="Image" src="https://github.com/user-attachments/assets/7edd76a6-622b-4ca8-83a8-fadf18316c3f" />
#
# Example of dialoge from the M&Ms:
#
# <img width="1388" height="631" alt="Image" src="https://github.com/user-attachments/assets/ce5483ed-30a9-4345-b3d6-f4fb65c77100" />
#
# Example of the quiz:
#
# <img width="1387" height="649" alt="Image" src="https://github.com/user-attachments/assets/7015af90-29f6-4f19-ad8f-87cf895b5317" />

# %% [markdown]
# ## Fundamentals of Javascript
#  Teaching lessons 3.12 Calling Procedures and 3.13 Developing Procedures helped me better understand how procedures make programs more organized and efficient. While teaching, I reinforced the difference between defining and calling a procedure and saw how parameters allow data to be passed and reused in different parts of a program. I also learned how important abstraction is for simplifying complex code and making it easier to read. By explaining these concepts to others, I realized how modular design and clear procedure names make problem-solving more manageable. Overall, teaching these lessons strengthened both my programming knowledge and my ability to explain coding concepts clearly.

# %% [markdown]
# ## West Coast Project - Food Submodule
# ### What I learned:
#  The Food Route helped me think critically about how to teach READ operations in databases using a fun, real-world context. I designed interactive examples like Korean BBQ queries, street taco filtering, and In-N-Out pagination to make SQL concepts engaging and practical. Building the lesson reinforced my understanding of SELECT statements, WHERE clauses, ORDER BY, LIMIT, and pattern matching, and it challenged me to explain these ideas clearly for others. Overall, developing this module strengthened both my technical SQL skills and my ability to translate complex coding concepts into an interactive experience.
#
# ### What I worked on:
#
# While creating the **Quest Chapter: The Food Route**, I developed the **progress check and quick quizzes** to help learners reinforce what they were learning. I designed them to align with each section, like SELECT queries for Korean BBQ, WHERE filtering for street tacos, and pagination for In-N-Out Burger. Working on these quizzes helped me think about **how students process SQL concepts**, the quizzes were short questions that would help reinforce the topic with **immediate feedback** to strengthen understanding. Including these checks made the lesson more interactive and ensured that learners could **apply concepts at each stage**. The progress check was just to help them keep track of what they finished.
#
# Example of the quiz:
#
# <img width="860" height="638" alt="Image" src="https://github.com/user-attachments/assets/759103f2-ae2d-4424-9b8b-72c734e93e6c" />
#
# Example of the progress checker:
#
# <img width="816" height="464" alt="Image" src="https://github.com/user-attachments/assets/c705e250-42ab-4361-a6f8-c618c6d00ffb" />
#
# ### What I would change:
#
# 1. **Add More Interactivity**
#    - Include live query editors or mini coding challenges so learners can **run queries and see results** immediately.
#    - Add drag-and-drop exercises for building SELECT statements.
#
# 2. **Visualize Data**
#    - Show results as tables, charts, or graphs to make patterns easier to understand.
#    - Include diagrams linking SQL concepts (like JOINs or WHERE filters) to the food examples.
#
# 3. **Make it more easy to understand for Beginners**
#    - Provide **step-by-step examples** before asking learners to write queries independently.
#    - Add hints or tooltips explaining clauses like ORDER BY, LIMIT, or LIKE.
#
# 4. **Expand Context or Scenarios**
#    - Include more diverse dishes, cities, or real-world filtering scenarios.
#    - Add mini “challenges” comparing price ranges, cuisine types, or nutritional info.
#
# 5. **Enhance Quizzes and Reflection**
#    - Include more **interactive questions** with instant feedback.
#    - Add reflective prompts, like “How would you find the cheapest premium dish?”
#
# 6. **Performance Notes**
#    - Show learners **why indexing matters** or how query structure affects speed.

# %% [markdown]
# ## Analytics
# Commits:
#
# <img width="912" height="582" alt="Image" src="https://github.com/user-attachments/assets/d60d5cfd-cf22-4584-9040-20632c59a888" />
#
# Grade Predictor:
#
# <img width="1223" height="619" alt="Image" src="https://github.com/user-attachments/assets/782c8bcb-6afa-4b98-a924-2e691ef8aff4" />
#
# Actions and Performace metrics:
#
# <img width="916" height="511" alt="Image" src="https://github.com/user-attachments/assets/9325c62b-aa36-42b6-bd60-bf85e6d2a324" />

# %% [markdown]
# ## Multiple Choice Review
# Score: 33/66
#
# Most missed topics:
#
#
#
# Topic summary:

# %% [markdown]
# <p style="color:orange; font-weight:bold;">Practice quiz questions corrections:</p>
#
# <div style="font-size:14px; line-height:1.5;">
#
# <p style="color:blue;"><strong>10-Writing code to use procedure DrawCircle</strong></p>
# <p><span style="color:red;">My mistake:</span> choosing option A, which made the circles move up and to the right each time. In that program, yPos increases by 2, so the circles end up at (3, 6), (5, 8), and (7, 10).</p>
# <p><span style="color:green;">The correct answer:</span> option B, because in that one yPos decreases by 2, making the circles move down and to the right instead. That gives the correct centers of (3, 6), (5, 4), and (7, 2), which matches the figure.</p>
#
# <p style="color:blue;"><strong>15-Internet communications characteristic</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> C, because every device connected to the Internet is assigned an Internet Protocol (IP) address. This address identifies the device and allows it to send and receive data across networks. It’s like a digital “home address” for communication on the Internet.</p>
#
# <p style="color:blue;"><strong>16-Consequences of downloading licensed music seller</strong></p>
# <p><span style="color:red;">I chose C, but that was incorrect.</span> The user’s download history can be used to recommend similar artists based on aggregated data from many users, so it’s actually very likely that similar artists would be suggested after the download.</p>
# <p><span style="color:green;">The correct answer:</span> D, because downloading the album from a licensed online music seller is legal. Since it’s not an illegal download, this action would not violate the Digital Millennium Copyright Act (DMCA).</p>
#
# <p style="color:blue;"><strong>18-Predicting births with a computer model</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> C, because removing details from the model would likely make it less accurate, not more. A model that ignores important factors can’t make precise predictions.</p>
#
# <p style="color:blue;"><strong>19-Library e-books metadata</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> A, because an archive of previous versions of the e-book is not typically part of metadata. Metadata usually contains information that helps identify and categorize the book, like the author and title (B), the publication date (C), and the genre (D).</p>
#
# <p style="color:blue;"><strong>21-Comparing robot algorithms</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> A, because the robot needs to move 2 squares to the right from its starting position and then 3 squares up to reach the gray square.</p>
# <p>Line 1: Move X Times with X = 2 moves the robot 2 squares forward (to the right).</p>
# <p>Line 2: Right X Times with X = 1 rotates the robot 90° to face upward.</p>
# <p>Line 3: Move X Times with X = 3 moves the robot 3 squares forward (up) to reach the gray square.</p>
#
# <p style="color:blue;"><strong>23-Redundant routing with four computers</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> B, because in that configuration there is only one path from computer P to computer S: P → R → Q → S. There is no alternative route, so redundant routing between P and S is not possible. The other configurations (A, C, and D) all have multiple paths connecting P and S, allowing for redundant routing if one connection fails.</p>
#
# <p style="color:blue;"><strong>24-Compression by replacing TH and IS with characters</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> C, because byte pair encoding is a lossless transformation. Even though it replaces repeated character pairs with single characters, the encoding algorithm saves a mapping of replacements. This mapping allows the original string to be fully reconstructed from the encoded string, so no data is lost.</p>
#
# <p style="color:blue;"><strong>25-Shortening strings by replacing TH and IS</strong></p>
# <p><span style="color:red;">I answered C, but that was incorrect.</span> The string MEET_ME_LATER actually can be shortened using byte pair encoding because it contains repeated pairs, like “ME,” which can be replaced to make the string shorter.</p>
# <p><span style="color:green;">The correct answer:</span> B, because LEVEL_UP does not have any repeated pairs of characters. Byte pair encoding only works when pairs appear more than once, so this string cannot be shortened using that method.</p>
#
# <p style="color:blue;"><strong>27-Guessing a secret number</strong></p>
# <p><span style="color:red;">I answered C, but that was incorrect.</span> If I set win ← true between lines 20 and 21, it would run after an incorrect guess, causing the loop to terminate even when the guess is wrong.</p>
# <p><span style="color:green;">The correct place to insert:</span> win ← true is between lines 9 and 10, right after displaying “You got it right!” This way, the loop only ends when the user actually guesses the secret number.</p>
#
# <p style="color:blue;"><strong>28-Text-editing application with binary sequences</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> C.</p>
# <p>Explanation: To assign a unique binary sequence to each character, the number of possible sequences must be at least 200. Each bit doubles the number of sequences:</p>
# <p>7 bits → 2⁷ = 128 (too few)</p>
# <p>8 bits → 2⁸ = 256 (enough)</p>
# <p>So the minimum number of bits needed is 8, not 7.</p>
#
# <p style="color:blue;"><strong>29-Diagram with three logic gates</strong></p>
# <p><span style="color:red;">I answered C, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> A, here’s why:</p>
# <p>For C: A = false, B = false → AND gate output = false</p>
# <p>C = true, D = true → OR gate output = true</p>
# <p>The second OR gate receives false and true → output = true</p>
# <p>The circuit only outputs false when both the AND gate and the first OR gate outputs are false. That happens with A = true, B = false, C = false, D = false.</p>
#
# <p style="color:blue;"><strong>31-Comparing loop algorithms with robots</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> B, because Program I does not correctly move the robot to the gray square; it repeats a fixed sequence of moves that doesn’t account for the robot’s starting position. Program II, however, uses a loop that repeats until the robot reaches the gray square and checks whether it can move forward or needs to rotate, ensuring the robot successfully reaches the goal.</p>
#
# <p style="color:blue;"><strong>33-Apartment rental Web site flowchart</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> A, because the flowchart sets include to true if either the apartment is on a floor greater than 10 or it has 3 bedrooms. This corresponds to the logical OR statement: include ← (floor > 10) OR (bedrooms = 3).</p>
#
# <p style="color:blue;"><strong>37-Comparing code segments to compute average from list</strong></p>
# <p><span style="color:red;">I answered B, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> C, because both code segments display the correct average. The difference is that Program I calculates the average inside the loop for each number in the list, performing the division multiple times, while Program II calculates the average once after summing all numbers, making it more efficient.</p>
#
# <p style="color:blue;"><strong>39-Internet open standards and protocols</strong></p>
# <p><span style="color:red;">I answered B, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> A, because open standards and protocols ensure that hardware and software from different manufacturers and developers can communicate with each other over the Internet. This interoperability is a key benefit, allowing devices and applications to work together seamlessly.</p>
#
# <p style="color:blue;"><strong>41-Computer science midterm and final with MAX</strong></p>
# <p><span style="color:red;">I answered A, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> C, because adjustedTotal ← Max(midtermExam, finalExam) + finalExam correctly calculates the total points according to the score replacement policy. Option A only assigns the larger of the two scores to adjustedTotal, which ignores the final exam score in the total points calculation.</p>
#
# <p style="color:blue;"><strong>43-Runtime of algorithm for online retailer</strong></p>
# <p><span style="color:red;">I answered B, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> A, because the number of steps grows as a polynomial function of n (specifically, roughly n²). Polynomial-time algorithms are considered to run in reasonable time even for large input sizes, unlike exponential-time algorithms, which quickly become impractical.</p>
#
# <p style="color:blue;"><strong>44-Using a 4 bit representation for integers</strong></p>
# <p><span style="color:red;">I answered C, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> B, because with 4 bits, the maximum nonnegative integer that can be represented is 15.</p>
# <p>4 + 8 = 12 → does not overflow.</p>
# <p>7 + 10 = 17 → overflow, since 17 > 15.</p>
# <p>12 + 3 = 15 → does not overflow, because 15 is within the 4-bit limit.</p>
#
# <p style="color:blue;"><strong>45-NAND logic gate</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> C, because a NAND gate outputs false only when both inputs are true. This behavior is modeled by the Boolean expression NOT (P AND Q), which inverts the result of an AND gate.</p>
#
# <p style="color:blue;"><strong>48-Science experiment with 75 percent successful trials</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> D, because 75% of trials are expected to be successful. Using RANDOM(1, 100) <= 75 ensures that, on average, 75 out of 100 random numbers will satisfy the condition and increment the successful count, while the remaining 25% will increment the unsuccessful count.</p>
#
# <p style="color:blue;"><strong>49-Completing code to display multiples of 5</strong></p>
# <p><span style="color:red;">I answered B, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> C, because the loop needs to iterate once for each multiple of 5 between start and end, inclusive. Using ((end − start) ÷ 5) + 1 gives the correct number of iterations. For example, if start = 35 and end = 50, this evaluates to ((50 − 35) ÷ 5) + 1 = 4, so the loop displays 35, 40, 45, and 50.</p>
#
# <p style="color:blue;"><strong>52-Algorithms to identify palindrome words in list</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> B, because the algorithm must first keep palindromes, then shorten each word to its first letter, and finally sort the resulting list alphabetically. Doing the steps in any other order would either remove necessary information too early or sort the wrong data.</p>
#
# <p style="color:blue;"><strong>54-Abstraction with procedures Square and Cube</strong></p>
# <p><span style="color:red;">I answered B, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> D, because the Power(n, m) procedure generalizes the functionality of Square and Cube by allowing any exponent m. Square is just Power(n, 2) and Cube is Power(n, 3), so Power captures the behavior of both procedures and more.</p>
#
# <p style="color:blue;"><strong>55-Results of the KeepPlaying procedure</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answer:</span> D, because the condition on line 5 checks whether the response is both "y" and "yes" at the same time. Since a user’s input can never equal both "y" and "yes" simultaneously, the condition is always false, and the procedure always returns false.</p>
#
# <p style="color:blue;"><strong>58-Defining Internet enabled crowdsourcing</strong></p>
# <p><span style="color:red;">I answered C, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> A, because statements I and II are true: the Internet provides participants access to tools, information, and professional knowledge, and it lowers geographic barriers so people from different locations can contribute. Statement III is false because not all computational problems can be solved in reasonable time, even with crowdsourcing or distributed approaches.</p>
#
# <p style="color:blue;"><strong>59-Movie studio media librarian</strong></p>
# <p><span style="color:red;">I answered C, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answer:</span> B, because using lossy compression reduces file size by discarding some data, which prevents the studio from accessing full-quality videos in the future. The other options support archival goals by ensuring compatibility, expandability, and reliability.</p>
#
# <p style="color:blue;"><strong>60-Managing complexity with abstraction</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answers:</span> A and D. Abstraction helps manage program complexity by replacing repeated code with a procedure (A), so the programmer doesn’t have to rewrite the same logic multiple times, and by grouping related variables into a single data structure like a list (D), which simplifies handling multiple values. Options B and C do not reduce program complexity; they only affect readability or typing convenience.</p>
#
# <p style="color:blue;"><strong>61-Data about students at East and West High schools</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answers:</span> A and B. The schools can create a single list of student names sorted by last name (A) because both data sets include first and last names. They can also calculate the average number of days students are absent (B) because both data sets include the days absent. They cannot determine which ZIP code is represented by the most students (C) because West High School’s data does not include ZIP codes.</p>
#
# <p style="color:blue;"><strong>62-Compare online encyclopedia with paper encyclopedia</strong></p>
# <p><span style="color:red;">I answered only B, but that was incorrect.</span></p>
# <p><span style="color:green;">The correct answers:</span> C and D, because a free online encyclopedia can reflect a larger number of perspectives (C) since many users can contribute, and it can be quickly updated (D) as new information becomes available. Option B is incorrect because the content can change over time, so it is not guaranteed to be the same every time it is accessed.</p>
#
# <p style="color:blue;"><strong>63-Use of isPrime procedure</strong></p>
# <p><span style="color:red;">I answered A and B, but that was partially incorrect.</span></p>
# <p><span style="color:green;">The correct lines to remove:</span> B and D. Line 4 resets count to 0 inside the loop, which prevents the program from keeping a running total, and line 9 incorrectly adds 1 to count for every number, even non-primes. Keeping line 1 ensures count starts at 0 before the loop begins, which is necessary.</p>
#
# <p style="color:blue;"><strong>64-Cloud computing and the Internet</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answers:</span> B and C, because cloud computing enhances collaboration (B) by allowing multiple users to access and work on shared resources simultaneously, and it introduces new data-security concerns (C) since data is stored on external servers that may be vulnerable to breaches. Options A and D are incorrect because redundancy is still necessary for reliability, and cloud computing does not reduce intellectual property concerns.</p>
#
# <p style="color:blue;"><strong>65-Correcting errors in procedure Multiply</strong></p>
# <p><span style="color:red;">I left this question blank.</span></p>
# <p><span style="color:green;">The correct answers:</span> B and D. The procedure only adds x to result a number of times equal to y, which works when y is positive. If y is negative (as in B or D), the loop condition count = y will never be met, so the procedure will not return the correct product. It works correctly when both x and y are positive or when x is negative and y is positive.</p>
#
# </div>

# %% [markdown]
# <p style="color:orange; font-weight:bold;">Most missed topics with the skills I lack and a summary of my answers:</p>
#
# <div style="font-size:14px; line-height:1.5;">
#
# <p style="color:blue;"><strong>1. Loops, Counters, and Algorithm Logic</strong></p>
# <p><span style="color:purple;"><strong>Skills:</strong></span> 1.D, 3.D, 4.B, 4.C</p>
# <p><span style="color:red;"><strong>Topics Missed:</strong></span></p>
# <ul>
# <li>Comparing loop algorithms with robots (Q14, Q31)</li>
# <li>Counting primes with loops (Q63)</li>
# <li>Computing averages efficiently (Q37)</li>
# <li>Skip counting integers (Q56)</li>
# <li>Guessing secret number placement logic (Q27)</li>
# </ul>
# <p><span style="color:green;"><strong>Summary:</strong></span></p>
# <ul>
# <li>Ensure counters are initialized outside loops.</li>
# <li>Update variables at the correct step inside loops.</li>
# <li>Loops should account for changing conditions (robot movement, guesses).</li>
# <li>Perform calculations outside repeated steps when possible for efficiency.</li>
# </ul>
#
# <p style="color:blue;"><strong>2. Procedures, Abstraction, and Parameterization</strong></p>
# <p><span style="color:purple;"><strong>Skills:</strong></span> 3.B, 3.C, 3.12, 3.13</p>
# <p><span style="color:red;"><strong>Topics Missed:</strong></span></p>
# <ul>
# <li>Using DrawCircle correctly (Q10)</li>
# <li>Abstraction with Square, Cube, and Power procedures (Q54)</li>
# <li>KeepPlaying procedure logic (Q55)</li>
# <li>Multiplying numbers with a procedure, including negatives (Q65)</li>
# </ul>
# <p><span style="color:green;"><strong>Summary:</strong></span></p>
# <ul>
# <li>Understand how procedure parameters affect results.</li>
# <li>Generalize repeated functionality instead of writing separate functions.</li>
# <li>Place logic correctly within procedures to handle all input cases.</li>
# </ul>
#
# <p style="color:blue;"><strong>3. Data, Metadata, and Data Handling</strong></p>
# <p><span style="color:purple;"><strong>Skills:</strong></span> 2.B, 2.C, 2.3, 5.B</p>
# <p><span style="color:red;"><strong>Topics Missed:</strong></span></p>
# <ul>
# <li>Library e-books metadata (Q19)</li>
# <li>Data from East and West High Schools (Q61)</li>
# <li>Online encyclopedia advantages (Q62)</li>
# <li>Palindrome word algorithm (Q52)</li>
# </ul>
# <p><span style="color:green;"><strong>Summary:</strong></span></p>
# <ul>
# <li>Know what metadata includes and excludes.</li>
# <li>Combine data only when fields match in format and meaning.</li>
# <li>Steps in algorithms matter (filter → shorten → sort).</li>
# </ul>
#
# <p style="color:blue;"><strong>4. Internet, Networking, and Cloud</strong></p>
# <p><span style="color:purple;"><strong>Skills:</strong></span> 4.A, 4.1, 5.A, 5.C</p>
# <p><span style="color:red;"><strong>Topics Missed:</strong></span></p>
# <ul>
# <li>Internet communications characteristics (Q15)</li>
# <li>Open standards and protocols (Q39)</li>
# <li>Crowdsourcing via Internet (Q58)</li>
# <li>Cloud computing effects (Q64)</li>
# </ul>
# <p><span style="color:green;"><strong>Summary:</strong></span></p>
# <ul>
# <li>Every device needs a unique IP for communication.</li>
# <li>Open standards enable interoperability.</li>
# <li>Internet lowers barriers but doesn’t solve all computational problems.</li>
# <li>Cloud enables collaboration but introduces security concerns.</li>
# </ul>
#
# <p style="color:blue;"><strong>5. Compression, Binary, and Encoding</strong></p>
# <p><span style="color:purple;"><strong>Skills:</strong></span> 2.1, 2.2, 3.C</p>
# <p><span style="color:red;"><strong>Topics Missed:</strong></span></p>
# <ul>
# <li>Byte pair encoding (Q24, Q25)</li>
# <li>Binary sequences for characters (Q28)</li>
# <li>4-bit integer overflow (Q44)</li>
# </ul>
# <p><span style="color:green;"><strong>Summary:</strong></span></p>
# <ul>
# <li>Byte pair encoding only works with repeated pairs.</li>
# <li>Minimum bits required = 8 for 200 characters.</li>
# <li>Integer limits are defined by bit representation; overflow occurs beyond max value.</li>
# </ul>
#
# <p style="color:blue;"><strong>6. Logic Gates and Digital Systems</strong></p>
# <p><span style="color:purple;"><strong>Skills:</strong></span> 3.5, 2.B</p>
# <p><span style="color:red;"><strong>Topics Missed:</strong></span></p>
# <ul>
# <li>NAND logic gate (Q45)</li>
# <li>Diagram with three logic gates (Q29)</li>
# </ul>
# <p><span style="color:green;"><strong>Summary:</strong></span></p>
# <ul>
# <li>NAND = NOT (AND).</li>
# <li>Logic gate outputs depend on both previous gate outputs and input combinations.</li>
# </ul>
#
# <p style="color:blue;"><strong>7. Security, Encryption, and Digital Ethics</strong></p>
# <p><span style="color:purple;"><strong>Skills:</strong></span> 5.E, 5.D, 5.C</p>
# <p><span style="color:red;"><strong>Topics Missed:</strong></span></p>
# <ul>
# <li>Consequences of downloading licensed music (Q16)</li>
# <li>Public key cryptography / symmetric encryption (Q47, Q51)</li>
# <li>Movie studio media librarian / lossy compression (Q59)</li>
# </ul>
# <p><span style="color:green;"><strong>Summary:</strong></span></p>
# <ul>
# <li>Legal downloads do not violate DMCA.</li>
# <li>Symmetric vs. public key encryption differs in key use.</li>
# <li>Lossy compression sacrifices quality; full-quality archiving requires lossless methods.</li>
# </ul>
#
# <p style="color:blue;"><strong>Summary of Skills You Lack Most</strong></p>
# <ul>
# <li>Loops, counters, and algorithm logic – handling iterations, placement of counters, and conditional checks.</li>
# <li>Procedures and abstraction – parameter usage, generalization, correct placement of logic inside functions.</li>
# <li>Data handling and metadata – understanding formats, combining datasets, and algorithmic step order.</li>
# <li>Internet, networking, and cloud – IP addresses, open standards, crowdsourcing, cloud security.</li>
# </ul>
#
# </div>

# %% [markdown]
# ## Night at the Museum
#
# The Night at the Museum event was both exciting and fulfilling. It was an amazing experience to see our West Coast Travel project come alive and watch parents, teachers, and students interact with our individual submodules. I especially enjoyed presenting the food module, where me and my team demonstrated the fundamentals of CRUD.
#
# What went well:
#
# Our presentations went smoothly with no technical issues, which made it easy to focus on engaging the audience. Many attendees seemed genuinely interested in the topic, asking questions and exploring the interactive elements. The hands-on features, in particular, captured attention and encouraged participants to actively participate, making the experience both educational and enjoyable. Overall, the combination of a seamless presentation and engaging activities created a positive and memorable experience for everyone involved.
#
# What I would do better:
#
# I would make sure our team has more areas set up to accommodate visitors and ensure the experience flows smoothly. I would also make the module more beginner-friendly, allowing attendees with little or no coding experience to engage easily and feel confident exploring the interactive elements. These changes would make the presentation even more accessible and enjoyable for everyone.

# %% [markdown]
# ## What I want to learn next in Computer Science Principles
#
# Next, I want to focus on improving my skills in LXD to make my coding more efficient, organized, and maintainable. I want to learn how to structure projects so that each component interacts seamlessly with others, which will help me create more complex and polished programs. In addition, I want to learn how to make better games, including designing more interactive features, smoother mechanics, and engaging visuals that enhance the player experience. I’m interested in exploring techniques for game logic, character behaviors, and level design that make games more fun and challenging. I also want to practice debugging and testing my projects more thoroughly, so I can identify issues quickly and make my programs more reliable. By combining these skills, I hope to develop projects that are not only functional but also creative, immersive, and enjoyable for users. Overall, my goal is to take the coding foundations I’ve built in AP CSP and apply them in more advanced, hands-on projects that push me to think critically and creatively.
